# %%
import numpy as np
from model_building import naive_model, tuned_model, evaluate_model
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the .npz file
data = np.load('data.npz')

# %%
# Access the arrays
X_train_balanced = data['X_train_balanced']
y_train_balanced = data['y_train_balanced']
X_valid_scaled = data['X_valid_scaled']
y_valid = data['y_valid']

# %%
xgb_model = naive_model(XGBClassifier(), X_train_balanced, y_train_balanced)
# XGBoost does not require tuning, but you can adjust hyperparameters if needed
evaluate_model(xgb_model, X_valid_scaled, y_valid)
# Out:
# Accuracy: 78.951%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84     69054
#            1       0.79      0.62      0.69     42589
#
#     accuracy                           0.79    111643
#    macro avg       0.79      0.76      0.77    111643
# weighted avg       0.79      0.79      0.78    111643
# array([[61948,  7106],
#        [16394, 26195]], dtype=int64)
